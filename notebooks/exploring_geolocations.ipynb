# %%
import geopandas as geo
from sqlalchemy import create_engine
from shapely.geometry import Polygon, MultiPolygon

# %%
files_path = "/Users/diegolopes/Documents/Education/Graduate/MasterDegree/Research/IBGE_layers/malha_municipal/1_Brasil"

engine = create_engine("postgresql://postgres:DoL#7478@localhost/geo_data")

# %%
mesorregioes = geo.read_file(f"{files_path}/BR_Mesorregioes_2022/BR_Mesorregioes_2022.shp")
microrregioes = geo.read_file(f"{files_path}/BR_Microrregioes_2022/BR_Microrregioes_2022.shp")
municipios = geo.read_file(f"{files_path}/BR_Municipios_2022/BR_Municipios_2022.shp")
pais = geo.read_file(f"{files_path}/BR_Pais_2022/BR_Pais_2022.shp")
rg_imediatas = geo.read_file(f"{files_path}/BR_RG_Imediatas_2022/BR_RG_Imediatas_2022.shp")
rg_intermediarias = geo.read_file(f"{files_path}/BR_RG_Intermediarias_2022/BR_RG_Intermediarias_2022.shp")
uf = geo.read_file(f"{files_path}/BR_UF_2022/BR_UF_2022.shp")

# %%
mesorregioes.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cd_meso   139 non-null    object
#  1   nm_meso   139 non-null    object
#  2   sigla_uf  139 non-null    object
#  3   area_km2  139 non-null    float64
#  4   geometry  139 non-null    geometry
# dtypes: float64(1), geometry(1), object(3)
# memory usage: 5.6+ KB

# %%
microrregioes.head()
# Out:
#   CD_MICRO          NM_MICRO SIGLA_UF   AREA_KM2  \
# 0    11001       Porto Velho       RO  65658.650
# 1    11002     Guajará-Mirim       RO  40792.646
# 2    11003         Ariquemes       RO  24333.565
# 3    11004         Ji-Paraná       RO  25090.399
# 4    11005  Alvorada D'Oeste       RO  15965.819
#
#                                             geometry
# 0  POLYGON ((-63.5243 -10.24964, -63.52192 -10.25...
# 1  POLYGON ((-63.68476 -12.45306, -63.68567 -12.4...
# 2  POLYGON ((-62.67077 -10.28778, -62.69302 -10.3...
# 3  POLYGON ((-62.15923 -11.06775, -62.16103 -11.0...
# 4  POLYGON ((-63.19546 -11.10339, -63.19459 -11.1...

# %%
municipios.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.1191, -60.81773 -13.12...

# %%
pais.head()
# Out:
#   NM_PAIS     AREA_KM2                                           geometry
# 0  Brasil  8510417.771  MULTIPOLYGON (((-41.82601 -2.75727, -41.82171 ...

# %%
rg_imediatas.head()
# Out:
#    CD_RGI       NM_RGI SIGLA_UF   AREA_KM2  \
# 0  110001  Porto Velho       RO  79943.767
# 1  110002    Ariquemes       RO  23260.950
# 2  110003         Jaru       RO  21853.300
# 3  110004    Ji-Paraná       RO  45080.055
# 4  110005       Cacoal       RO  36166.460
#
#                                             geometry
# 0  POLYGON ((-65.3815 -10.42907, -65.38013 -10.42...
# 1  POLYGON ((-63.09956 -9.48078, -63.06119 -9.471...
# 2  POLYGON ((-62.42317 -9.80583, -62.42287 -9.804...
# 3  POLYGON ((-62.52526 -10.70947, -62.49998 -10.6...
# 4  POLYGON ((-61.7423 -11.33348, -61.74303 -11.33...

# %%
rg_intermediarias.head()
# Out:
#   CD_RGINT         NM_RGINT SIGLA_UF    AREA_KM2  \
# 0     1101      Porto Velho       RO  125058.017
# 1     1102        Ji-Paraná       RO  112696.154
# 2     1201       Rio Branco       AC   78721.076
# 3     1202  Cruzeiro do Sul       AC   85452.353
# 4     1301           Manaus       AM  566706.115
#
#                                             geometry
# 0  POLYGON ((-61.95442 -9.94968, -61.95552 -9.950...
# 1  POLYGON ((-60.91898 -13.54833, -60.91651 -13.5...
# 2  POLYGON ((-67.97684 -9.35273, -67.88121 -9.396...
# 3  POLYGON ((-73.12803 -8.77124, -73.12998 -8.769...
# 4  POLYGON ((-61.29357 -4.71189, -61.3086 -4.7493...

# %%
uf.head()
# Out:
#   CD_UF      NM_UF SIGLA_UF NM_REGIAO     AREA_KM2  \
# 0    12       Acre       AC     Norte   164173.429
# 1    13   Amazonas       AM     Norte  1559255.881
# 2    15       Pará       PA     Norte  1245870.704
# 3    16      Amapá       AP     Norte   142470.762
# 4    17  Tocantins       TO     Norte   277423.627
#
#                                             geometry
# 0  POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...
# 1  POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...
# 2  MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...
# 3  MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...
# 4  POLYGON ((-48.2483 -13.19239, -48.24844 -13.19...

# %%
files_path = "/Users/diegolopes/Documents/Education/Graduate/MasterDegree/Research/IBGE_layers/malha_setores_censitários"

distritos = geo.read_file(f"{files_path}/BR_Malha_Preliminar_Distrito_2022/BR_Malha_Preliminar_Distrito_2022.shp")
subdistritos = geo.read_file(f"{files_path}/BR_Malha_Preliminar_Subdistrito_2022/BR_Malha_Preliminar_Subdistrito_2022.shp")
setores_censitarios = geo.read_file(f"{files_path}/BR_Malha_Preliminar_2022/BR_Malha_Preliminar_2022.shp")

# %%
distritos.head()
# Out:
#   CD_REGIAO NM_REGIAO CD_UF     NM_UF   CD_MUN                 NM_MUN  \
# 0         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 1         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 2         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 3         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 4         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
#
#      CD_DIST                    NM_DIST  \
# 0  110001505      Alta Floresta D'Oeste
# 1  110001515         Filadélfia d'Oeste
# 2  110001520                Izidolândia
# 3  110001525         Nova Gease d'Oeste
# 4  110001530  Rolim de Moura do Guaporé
#
#                                             geometry
# 0  POLYGON ((-61.93075 -11.97349, -61.93234 -11.9...
# 1  POLYGON ((-62.06668 -12.26935, -62.01564 -12.2...
# 2  POLYGON ((-62.17675 -12.5004, -62.14396 -12.50...
# 3  POLYGON ((-62.4531 -11.96851, -62.453 -11.9684...
# ...

# %%
subdistritos.head()
# Out:
#   CD_REGIAO NM_REGIAO CD_UF     NM_UF   CD_MUN                 NM_MUN  \
# 0         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 1         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 2         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 3         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
# 4         1     Norte    11  Rondônia  1100015  Alta Floresta D'Oeste
#
#      CD_DIST                    NM_DIST   CD_SUBDIST NM_SUBDIST  \
# 0  110001505      Alta Floresta D'Oeste  11000150500       None
# 1  110001515         Filadélfia d'Oeste  11000151500       None
# 2  110001520                Izidolândia  11000152000       None
# 3  110001525         Nova Gease d'Oeste  11000152500       None
# 4  110001530  Rolim de Moura do Guaporé  11000153000       None
#
#                                             geometry
# 0  POLYGON ((-61.93075 -11.97349, -61.93234 -11.9...
# ...

# %%
setores_censitarios.head()
# Out:
#            CD_SETOR  AREA_KM2 CD_REGIAO NM_REGIAO CD_UF     NM_UF   CD_MUN  \
# 0  110001505000001P  0.425739         1     Norte    11  Rondônia  1100015
# 1  110001505000002P  0.539305         1     Norte    11  Rondônia  1100015
# 2  110001505000003P  0.236220         1     Norte    11  Rondônia  1100015
# 3  110001505000004P  0.211866         1     Norte    11  Rondônia  1100015
# 4  110001505000005P  0.806025         1     Norte    11  Rondônia  1100015
#
#                   NM_MUN    CD_DIST                NM_DIST   CD_SUBDIST  \
# 0  Alta Floresta D'Oeste  110001505  Alta Floresta D'Oeste  11000150500
# 1  Alta Floresta D'Oeste  110001505  Alta Floresta D'Oeste  11000150500
# 2  Alta Floresta D'Oeste  110001505  Alta Floresta D'Oeste  11000150500
# 3  Alta Floresta D'Oeste  110001505  Alta Floresta D'Oeste  11000150500
# 4  Alta Floresta D'Oeste  110001505  Alta Floresta D'Oeste  11000150500
#
#   NM_SUBDIST CD_MICRO NM_MICRO CD_MESO            NM_MESO  CD_RGI  NM_RGI  \
# ...

# %%
mesorregioes.columns = map(str.lower, mesorregioes.columns)
mesorregioes
# Out:
#     cd_meso            nm_meso sigla_uf    area_km2  \
# 0      1101    Madeira-Guaporé       RO  106451.296
# 1      1102  Leste Rondoniense       RO  131302.876
# 2      1201      Vale do Juruá       AC   85452.353
# 3      1202       Vale do Acre       AC   78721.076
# 4      1301   Norte Amazonense       AM  404888.525
# ..      ...                ...      ...         ...
# 134    5202       Norte Goiano       GO   56552.909
# 135    5203      Centro Goiano       GO   40843.444
# 136    5204       Leste Goiano       GO   55562.498
# 137    5205         Sul Goiano       GO  131599.533
# 138    5301   Distrito Federal       DF    5760.784
#
#                                               geometry
# 0    POLYGON ((-63.68476 -12.45306, -63.68567 -12.4...
# 1    POLYGON ((-62.41771 -13.11894, -62.41902 -13.1...
# 2    POLYGON ((-73.12803 -8.77124, -73.12998 -8.769...
# 3    POLYGON ((-67.97684 -9.35273, -67.88121 -9.396...
# 4    POLYGON ((-66.00136 -2.14483, -66.01132 -2.141...
# ...

# %%
mesorregioes.to_postgis("mesorregiao_teste", engine, if_exists="append", index=False)

# %%
print(mesorregioes.crs)
# Out:
# EPSG:4674
